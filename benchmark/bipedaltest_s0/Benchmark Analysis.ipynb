# %%
import numpy as np
import pandas as pd

# %%
results = pd.read_csv("progress.txt", sep="\t")

# %%
results.head()
# Out:
#    Epoch  AverageEpRet   StdEpRet   MaxEpRet   MinEpRet      EpLen  \
# 0      0   -110.542440  16.138834 -64.934720 -125.75528  320.46155
# 1      1   -103.955770  20.717321 -63.341377 -121.64789  381.00000
# 2      2   -104.806755  20.972946 -59.336060 -129.78750  431.36365
# 3      3   -101.209250  16.964275 -52.117603 -118.21396  355.81818
# 4      4   -104.323340  16.005410 -65.980220 -121.33365  477.50000
#
#    AverageVVals  StdVVals   MaxVVals   MinVVals  TotalEnvInteracts    LossPi  \
# 0      0.122847  0.235288   0.797657  -0.803871               4800  0.006660
# 1    -12.936625  0.324581 -11.485338 -13.514050               9600  0.028801
# 2    -17.835690  0.099049 -16.953754 -17.984688              14400  0.008391
# 3    -22.901255  0.097048 -22.418869 -23.027157              19200  0.001301
# 4    -26.559675  0.053739 -25.984570 -26.634472              24000  0.018209
#
#         LossV  DeltaLossPi  DeltaLossV   Entropy        KL       Time
# ...

# %%
results[-33:]["AverageEpRet"].mean()
# Out:
# 89.909469666666666
